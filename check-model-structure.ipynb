# %%
import mxnet as mx
sym, arg_params, aux_params = mx.model.load_checkpoint('./models/r100-arcface-emore/model', 1)

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

# %%
mx.viz.plot_network(sym)
#digraph.render()
