# %%
# !nvidia-smi

from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/insightface-ilfw-real-time/

# !pip install -U mxnet-cu101==1.7.0
# Out:
# Thu May 13 22:10:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !chmod u+x start_train.sh
! ./start_train.sh
# Out:
# ': not a valid identifier
# Insightface Model Training Ver. 1.7.5 R100 - 600 Id - With Mask - 64 batch size
# gpu num: 1
# prefix ./models/r100-arcface-emore/model
# image_size [112, 112]
# num_classes 480
# ...

# %%
# !chmod u+x start_tune.sh
! ./start_tune.sh

# %%
# !chmod u+x start_pre_trained.sh
! ./start_pre_trained.sh

# %%
# !chmod u+x start_verify_tuned.sh
! ./start_verify_tuned.sh

# %%
# !chmod u+x start_verify_scratch.sh
! ./start_verify_scratch.sh

# %%
# !chmod u+x start_verify_pre_trained.sh
! ./start_verify_pre_trained.sh
# Out:
# ': not a valid identifier
# Insightface Model Verification Ver. 1.2 R100 - PreTrained - 600 Id - With Mask - 64 batch size
# image_size [112, 112]
# model number 1
# loading ./models/model-r100-ii/model 1
# [00:56:51] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.2.0. Attempting to upgrade...
# [00:56:51] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# model loading time 4.014874
# loading..  ilfw
# loading bin 0
# loading bin 1000
# loading bin 2000
# loading bin 3000
# loading bin 4000
# loading bin 5000
# (5578, 3, 112, 112)
# loading..  ilfw-test
# loading bin 0
# loading bin 1000
# loading bin 2000
# loading bin 3000
# loading bin 4000
# loading bin 5000
# (5434, 3, 112, 112)
# testing verification..
# (5578, 512)
# infer time 44.16904099999999
# [ilfw]XNorm: 21.235010
# [ilfw]Accuracy: 0.00000+-0.00000
# [ilfw]Accuracy-Flip: 0.97884+-0.01817
# Max of [ilfw] is 0.97884
# testing verification..
# (5434, 512)
# ...
